# %% [markdown]
# # Spacy demo

# %% [markdown]
# In this notebook, we will explore the [Spacy](https://spacy.io/) tool by using Fake News dataset.
#
# Let us import spacy and also import the 'english' language model.

# %%
import numpy as np
import pandas as pd
import spacy

# Import the english language model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Let us look at the number of rows and columns present in the dataset.

# %%
df = pd.read_csv("fake.csv")
df.shape
# Out:
# (12999, 20)

# %% [markdown]
# The description of the columns are as follows:
#
# * uuid - Unique identifier
# * ord_in_thread
# * author - author of story
# * published - date published
# * title - title of the story
# * text - text of story
# * language - data from webhose.io
# * crawled - date the story was archived
# * site_url - site URL from BS detector
# * country - data from webhose.io
# * domain_rank - data from webhose.io
# * thread_title
# * spam_score - data from webhose.io
# * main_img_url - image from story
# * replies_count - number of replies
# * participants_count - number of participants
# * likes - number of Facebook likes
# * comments - number of Facebook comments
# * shares - number of Facebook shares
# * type - type of website (label from BS detector)
#
# Now let us look at the top few rows of the dataset to gain some more understanding.

# %%
df.head()
# Out:
#                                        uuid  ord_in_thread  \
# 0  6a175f46bcd24d39b3e962ad0f29936721db70db              0
# 1  2bdc29d12605ef9cf3f09f9875040a7113be5d5b              0
# 2  c70e149fdd53de5e61c29281100b9de0ed268bc3              0
# 3  7cf7c15731ac2a116dd7f629bd57ea468ed70284              0
# 4  0206b54719c7e241ffe0ad4315b808290dbe6c0f              0
#
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...
# 1  Re: Why Did Attorney General Loretta Lynch Ple...
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
#
#                                                 text language  \
# 0  Print They should pay all the back all the mon...  english
# 1  Why Did Attorney General Loretta Lynch Plead T...  english
# 2  Red State : \nFox News Sunday reported this mo...  english
# 3  Email Kayla Mueller was a prisoner and torture...  english
# 4  Email HEALTHCARE REFORM TO MAKE AMERICA GREAT ...  english
#
#                          crawled             site_url country  domain_rank  \
# 0  2016-10-27T01:49:27.168+03:00  100percentfedup.com      US      25689.0
# 1  2016-10-29T08:47:11.259+03:00  100percentfedup.com      US      25689.0
# 2  2016-10-31T01:41:49.479+02:00  100percentfedup.com      US      25689.0
# 3  2016-11-01T15:46:26.304+02:00  100percentfedup.com      US      25689.0
# 4  2016-11-01T23:59:42.266+02:00  100percentfedup.com      US      25689.0
#
#                                         thread_title  spam_score  \
# 0  Muslims BUSTED: They Stole Millions In Gov’t B...       0.000
# 1  Re: Why Did Attorney General Loretta Lynch Ple...       0.000
# 2  BREAKING: Weiner Cooperating With FBI On Hilla...       0.000
# 3  PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...       0.068
# 4  FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...       0.865
#
#                                         main_img_url  replies_count  \
# 0  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 1  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 2  http://bb4sp.com/wp-content/uploads/2016/10/Fu...              0
# 3  http://100percentfedup.com/wp-content/uploads/...              0
# 4  http://100percentfedup.com/wp-content/uploads/...              0
#
#    participants_count  likes  comments  shares  type
# 0                   1      0         0       0  bias
# 1                   1      0         0       0  bias
# 2                   1      0         0       0  bias
# 3                   0      0         0       0  bias
# 4                   0      0         0       0  bias

# %% [markdown]
# Columns "title", "text" and "thread_title" has textual data. For this introduction, let us concentrate on the 'title' column. So let us look at the top few rows of the columns alone

# %%
df["title"].head()
# Out:
# 0    Muslims BUSTED: They Stole Millions In Gov’t B...
# 1    Re: Why Did Attorney General Loretta Lynch Ple...
# 2    BREAKING: Weiner Cooperating With FBI On Hilla...
# 3    PIN DROP SPEECH BY FATHER OF DAUGHTER Kidnappe...
# 4    FANTASTIC! TRUMP'S 7 POINT PLAN To Reform Heal...
# Name: title, dtype: object

# %% [markdown]
# **Word-Level Attributes:**
#
# Just calling the function "nlp" on the text column gets us a lot of information. Let us take an example row from the dataset and then apply the same.

# %%
txt = df["title"][1009]
txt
# Out:
# "Queen Elizabeth II owns every dolphin in Britain and doesn't need a driving licence and doesn't pay tax — here are the incredible powers you didn't know the monarchy has"

# %%
doc = nlp(txt)    
olist = []
for token in doc:
    l = [token.text,
        token.idx,
        token.lemma_,
        token.is_punct,
        token.is_space,
        token.shape_,
        token.pos_,
        token.tag_]
    olist.append(l)
    
odf = pd.DataFrame(olist)
odf.columns= ["Text", "StartIndex", "Lemma", "IsPunctuation", "IsSpace", "WordShape", "PartOfSpeech", "POSTag"]
odf
# Out:
#           Text  StartIndex       Lemma  IsPunctuation  IsSpace WordShape  \
# 0        Queen           0       Queen          False    False     Xxxxx
# 1    Elizabeth           6   Elizabeth          False    False     Xxxxx
# 2           II          16          II          False    False        XX
# 3         owns          19         own          False    False      xxxx
# 4        every          24       every          False    False      xxxx
# 5      dolphin          30     dolphin          False    False      xxxx
# 6           in          38          in          False    False        xx
# 7      Britain          41     Britain          False    False     Xxxxx
# 8          and          49         and          False    False       xxx
# 9         does          53          do          False    False      xxxx
# 10         n't          57         not          False    False       x'x
# 11        need          61        need          False    False      xxxx
# 12           a          66           a          False    False         x
# 13     driving          68       drive          False    False      xxxx
# 14     licence          76     licence          False    False      xxxx
# 15         and          84         and          False    False       xxx
# 16        does          88          do          False    False      xxxx
# 17         n't          92         not          False    False       x'x
# 18         pay          96         pay          False    False       xxx
# 19         tax         100         tax          False    False       xxx
# 20           —         104           —           True    False         —
# 21        here         106        here          False    False      xxxx
# 22         are         111          be          False    False       xxx
# 23         the         115         the          False    False       xxx
# 24  incredible         119  incredible          False    False      xxxx
# 25      powers         130       power          False    False      xxxx
# 26         you         137         you          False    False       xxx
# 27         did         141          do          False    False       xxx
# 28         n't         144         not          False    False       x'x
# 29        know         148        know          False    False      xxxx
# 30         the         153         the          False    False       xxx
# 31    monarchy         157    monarchy          False    False      xxxx
# 32         has         166        have          False    False       xxx
#
#    PartOfSpeech POSTag
# 0         PROPN    NNP
# 1         PROPN    NNP
# 2         PROPN    NNP
# 3          VERB    VBZ
# 4           DET     DT
# 5          NOUN     NN
# 6           ADP     IN
# 7         PROPN    NNP
# 8         CCONJ     CC
# 9           AUX    VBZ
# 10         PART     RB
# 11         VERB     VB
# 12          DET     DT
# 13         VERB    VBG
# 14         NOUN     NN
# 15        CCONJ     CC
# 16          AUX    VBZ
# 17         PART     RB
# 18         VERB     VB
# 19         NOUN     NN
# 20        PUNCT      :
# 21          ADV     RB
# 22          AUX    VBP
# 23          DET     DT
# 24          ADJ     JJ
# 25         NOUN    NNS
# 26         PRON    PRP
# 27          AUX    VBD
# 28         PART     RB
# 29         VERB     VB
# 30          DET     DT
# 31         NOUN     NN
# 32         VERB    VBZ

# %% [markdown]
# So using "nlp" we got a lot of information. The details are as follows:
#
# * Text - Tokenized word
# * StartIndex - Index at which the word starts in the sentence
# * Lemma - Lemma of the word (we need not do lemmatization separately)
# * IsPunctuation - Whether the given word is a punctuation or not
# * IsSpace - Whether the given word is just a white space or not
# * WordShape - Gives information about the shape of word (If all letters are in upper case, we will get XXXXX, if all in lower case then xxxxx, if the first letter is upper and others lower then Xxxxx and so on)
# * PartOfSpeech - Part of speech of the word
# * POSTag - Tag for part of speech of word

# %% [markdown]
# **Named Entity Recognition:**
#
# A named entity is a "real-world object" that's assigned a name – for example, a person, a country, a product or a book title.
#
# We also get named entity recognition as part of spacy package. It is inbuilt in the english language model and we can also train our own entities if needed.

# %%
doc = nlp(txt)
olist = []
for ent in doc.ents:
    olist.append([ent.text, ent.label_])
    
odf = pd.DataFrame(olist)
odf.columns = ["Text", "EntityType"]
odf
# Out:
#       Text EntityType
# 0  Britain        GPE

# %% [markdown]
# The complete list of different entity types can be seen [here](https://spacy.io/usage/linguistic-features#entity-types)
#
# Spacy also includes a [displacy visualizer](displaCy visualizer with Jupyter support) with jupyter notebook support. This can be used to visualize the named entity recognition data.

# %%
from spacy import displacy
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Queen Elizabeth II owns every dolphin in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and doesn't need a driving licence and doesn't pay tax — here are the incredible powers you didn't know the monarchy has</div></span>

# %% [markdown]
# Wow. This one looks cool. We can also take one more example and visualize the same.

# %%
txt = df["title"][3003]
doc = nlp(txt)
colors = {'GPE': 'lightblue', 'NORP':'lightgreen'}
options = {'ents': ['GPE', 'NORP'], 'colors': colors}
displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  calls for end to
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saudi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  airstrikes in
# <mark class="entity" style="background: lightblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yemen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </div></span>

# %% [markdown]
# **Noun Phrase Chunking:**
#
# Noun chunks are "base noun phrases" – flat phrases that have a noun as their head. You can think of noun chunks as a noun plus the words describing the noun – for example, "the lavish green grass" or "the world’s largest tech fund".
#
# Now let us look at how to do noun phrase chunking using spacy. In addition to noun phrase chunking, spacy also gets us the root of the noun.

# %%
txt = df["title"][2012]
print(txt)
# Out:
# Nukes and the UN: a Historic Treaty to Ban Nuclear Weapons

# %%
doc = nlp(txt)
olist = []
for chunk in doc.noun_chunks:
    olist.append([chunk.text, chunk.label_, chunk.root.text])
odf = pd.DataFrame(olist)
odf.columns = ["NounPhrase", "Label", "RootWord"]
odf
# Out:
#             NounPhrase Label RootWord
# 0                Nukes    NP    Nukes
# 1               the UN    NP       UN
# 2    a Historic Treaty    NP   Treaty
# 3  Ban Nuclear Weapons    NP  Weapons

# %% [markdown]
# **Dependency Parser**
#
# A dependency parser analyzes the grammatical structure of a sentence, establishing relationships between "head" words and words which modify those heads - [Stanford NLP](https://nlp.stanford.edu/software/nndep.html)
#
# Spacy can be used to create these dependency parsers which can be used in a variety of tasks.

# %%
doc = nlp(df["title"][1009])
olist = []
for token in doc:
    olist.append([token.text, token.dep_, token.head.text, token.head.pos_,
          [child for child in token.children]])
odf = pd.DataFrame(olist)
odf.columns = ["Text", "Dep", "Head text", "Head POS", "Children"]
odf
# Out:
#           Text       Dep Head text Head POS                        Children
# 0        Queen  compound        II    PROPN                              []
# 1    Elizabeth  compound        II    PROPN                              []
# 2           II     nsubj      owns     VERB              [Queen, Elizabeth]
# 3         owns     ccomp       are      AUX        [II, dolphin, and, need]
# 4        every       det   dolphin     NOUN                              []
# 5      dolphin      dobj      owns     VERB                     [every, in]
# 6           in      prep   dolphin     NOUN                       [Britain]
# 7      Britain      pobj        in      ADP                              []
# 8          and        cc      owns     VERB                              []
# 9         does       aux      need     VERB                              []
# 10         n't       neg      need     VERB                              []
# 11        need      conj      owns     VERB  [does, n't, licence, and, pay]
# 12           a       det   licence     NOUN                              []
# 13     driving  compound   licence     NOUN                              []
# 14     licence      dobj      need     VERB                    [a, driving]
# 15         and        cc      need     VERB                              []
# 16        does       aux       pay     VERB                              []
# 17         n't       neg       pay     VERB                              []
# 18         pay      conj      need     VERB                [does, n't, tax]
# 19         tax      dobj       pay     VERB                              []
# 20           —     punct       are      AUX                              []
# 21        here    advmod       are      AUX                              []
# 22         are      ROOT       are      AUX    [owns, —, here, powers, has]
# 23         the       det    powers     NOUN                              []
# 24  incredible      amod    powers     NOUN                              []
# 25      powers      attr       are      AUX         [the, incredible, know]
# 26         you     nsubj      know     VERB                              []
# 27         did       aux      know     VERB                              []
# 28         n't       neg      know     VERB                              []
# 29        know     relcl    powers     NOUN       [you, did, n't, monarchy]
# 30         the       det  monarchy     NOUN                              []
# 31    monarchy      dobj      know     VERB                           [the]
# 32         has      conj       are      AUX                              []

# %% [markdown]
# The description of the columns are
# * Text: The original token text.
# * Dep: The syntactic relation connecting child to head.
# * Head text: The original text of the token head.
# * Head POS: The part-of-speech tag of the token head.
# * Children: The immediate syntactic dependents of the token.
#
# The best way to understand the dependency parser is to visualize the same and looking at it.

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a41567efca14bc7b65ecf623cf64ac6-0" class="displacy" width="2930" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Queen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Elizabeth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">II</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">owns</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">dolphin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Britain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">driving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">licence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">does</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">pay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">tax —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">here</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">incredible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">powers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">n't</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">know</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">monarchy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</t

# %%
doc = nlp(df["title"][3012])
displacy.render(doc, style='dep', jupyter=True, options={'distance': 60})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8829dff38848408ba2705bd76c3186c8-0" class="displacy" width="710" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Evangelicals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="110">Across</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="110">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Spectrum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Clarifying</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Marriage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">Core</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Belief</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-0" stroke-width="2px" d="M70,92.0 C70,2.0 350.0,2.0 350.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,94.0 L62,82.0 78,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-1" stroke-width="2px" d="M70,92.0 C70,62.0 100.0,62.0 100.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M100.0,94.0 L108.0,82.0 92.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-2" stroke-width="2px" d="M190,92.0 C190,62.0 220.0,62.0 220.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,94.0 L182,82.0 198,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-3" stroke-width="2px" d="M130,92.0 C130,32.0 225.0,32.0 225.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,94.0 L233.0,82.0 217.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-4" stroke-width="2px" d="M310,92.0 C310,62.0 340.0,62.0 340.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,94.0 L302,82.0 318,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-5" stroke-width="2px" d="M370,92.0 C370,62.0 400.0,62.0 400.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,94.0 L408.0,82.0 392.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-6" stroke-width="2px" d="M370,92.0 C370,32.0 465.0,32.0 465.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M465.0,94.0 L473.0,82.0 457.0,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-7" stroke-width="2px" d="M550,92.0 C550,32.0 645.0,32.0 645.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,94.0 L542,82.0 558,82.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8829dff38848408ba2705bd76c3186c8-0-8" stroke-width="2px" d="M610,92.0 C610,62.0 640.0,62.0 640.0,92.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8829dff38848408ba2705bd76c3186c8-0-8" class="d

# %% [markdown]
# **Word Similarity:**
#
# Spacy has word vector model as well. So we can use the same to find similar words. The list of available models can be seen [here](https://spacy.io/models/).
#
# For our case, let us use the 'en_core_web_lg' model available in spacy (more details about the model can be accessed in this [link](https://spacy.io/models/en#en_core_web_lg)). First step is to load the model.

# %%
nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# Now we can use the cosine similarity to find the words that are similar to the word "Queen".

# %%
from scipy import spatial
cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

queen = nlp.vocab['Queen'].vector
computed_similarities = []
for word in nlp.vocab:
    # Ignore words without vectors
    if not word.has_vector:
        continue
    similarity = cosine_similarity(queen, word.vector)
    computed_similarities.append((word, similarity))

computed_similarities = sorted(computed_similarities, key=lambda item: -item[1])
print([w[0].text for w in computed_similarities[:10]])
# Out:
# ['Queen', 'Miss', 'she', 'St', 'r.', 'She', 'St.', 'Mont.', 'Mrs', ';-D']

# %% [markdown]
# Different versions of king and queen came out as the top similar words. Now let us take the other important words from the sentence "Elizabeth", "Britain", "Dolphin" and also "King' and check the similarity.

# %%
queen = nlp.vocab['Queen']
elizabeth = nlp.vocab['Elizabeth']
britain = nlp.vocab['Britain']
dolphin = nlp.vocab['Dolphin']
king = nlp.vocab['King']
 
print("Word similarity score between Queen and Elizabeth : ",queen.similarity(elizabeth))
print("Word similarity score between Queen and Britain : ",queen.similarity(britain))
print("Word similarity score between Queen and Dolphin : ",queen.similarity(dolphin))
print("Word similarity score between Queen and King : ",queen.similarity(king))
# Out:
# Word similarity score between Queen and Elizabeth :  0.5465951561927795
# Word similarity score between Queen and Britain :  0.29826614260673523
# Word similarity score between Queen and Dolphin :  0.19133657217025757
# Word similarity score between Queen and King :  0.659298300743103

# %% [markdown]
# "King" is the most similar word followed by "Elizabeth" and "Britain".

# %% [markdown]
# **References:**
# 1. [Complete Guide to Spacy](https://nlpforhackers.io/complete-guide-to-spacy/)
# 2. [Spacy documentation](https://spacy.io/)
#
# **More to come. Stay tuned.!**
